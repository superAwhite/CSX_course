# %%
import requests as rq
from bs4 import BeautifulSoup as bs
import lxml
import pandas as pd
import numpy as np

# %% [markdown]
# # 構想 1: 驗證氣溫與購買商品的關係
# ### ex:可以在夏季時，推短袖買一送一，長袖外套半價等

# %%
#for month in range(13):
   # url = 'https://www.cwb.gov.tw/V7/climate/monthlyData/Data/mD2017%s.htm' %(str(month))
df=pd.read_html('https://www.cwb.gov.tw/V7/climate/monthlyData/Data/mD20171.htm')

# %%
type(df)
# Out:
# list

# %%
df[0]
# Out:
#                                                   0      1        2    \
# 0                                       2017年01月 氣象資料    NaN      NaN
# 1   項目  溫度(℃)  雨量  風速(公尺/秒)/風向  (360°)/日期  相對溼度(%)...     項目    溫度(℃)
# 2                                                  項目  溫度(℃)       雨量
# 3                                                  測站     平均  最高/  日期
# 4                                                 阿里山    8.3   17.7/5
# 5                                                  鞍部   11.6  22.5/29
# 6                                                  板橋   18.1   27.3/1
# 7                                                  成功   20.1  27.2/30
# 8                                                  嘉義   19.0  28.7/29
# 9                                                  大武   21.8   27.9/8
# 10                                                東吉島   19.3   24.5/8
# 11                                                 恆春   22.7  28.7/19
# ...

# %% [markdown]
# ## 抓氣象局台北測站的2017月平均溫度

# %%
df[0][1][25]
# Out:
# '18.3'

# %% [markdown]
# # 構想 2:能依照當時各地區氣候在官網放相對應的商品
# ### ex:若台北正在下雨，在官網放雨衣、雨傘等商品
