# %%
import requests
import json
import numpy as np
import jieba

# %%
url =  "https://graph.facebook.com/v2.12/DonaldTrump?fields=posts.limit(100)&access_token=EAACEdEose0cBAPZB4XJxVAjJz6TqZANC9Ng11fQIC3lz4ZAS9ujmsJ4aA2Eype5YQlYjUif9T9ZA3NhTcZA8SzaTFQQqZC28IlL4mTq8aeIe9EEJKL8y5y8EedyLmwnipSY6SDQZAQ9ldXYqoHeF8qRXP5jcpyMSDZC9LLHgylWtDbQf5IiHmUkkwZCKDSiZBZAeue5jbnRtLKy2QZDZD"

# %%
res = requests.get(url)

# %%
decoder = json.JSONDecoder()
s = decoder.decode(res.text)

# %%
# 5 33 92 有問題的貼文((沒message 只有story)).

# %%
gg=[]

# %%
for i in range(93,100):
    gg.append(s['posts']['data'][i]['message'])

# %%
len(gg)
# Out:
# 97

# %%
aa = ''.join(gg)

# %%
from wordcloud import WordCloud 
wordcloud = WordCloud().generate(aa)

# %%
import matplotlib.pyplot as plt 
plt.imshow(wordcloud, interpolation='bilinear') 
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
#  - 可看出"川普"，"三月"，"會有名主黨會議"
